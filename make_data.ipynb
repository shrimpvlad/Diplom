# %%
import numpy as np
import quaternion
import pandas as pd
import scipy.interpolate
import math
from math import sqrt, acos
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

imu = [
       "imu1.csv", "imu2.csv", "imu3.csv", "imu4.csv", "imu5.csv", 
       "imu6.csv", "imu7.csv", "imu8.csv", "imu9.csv", "imu10.csv", 
       "imu11.csv", "imu12.csv", "imu13.csv", "imu14.csv", "imu15.csv",
       "imu16.csv", "imu17.csv", "imu18.csv", "imu19.csv", "imu20.csv",
       "imu21.csv", "imu22.csv", "imu23.csv", "imu24.csv", "imu25.csv",
       "imu26.csv", "imu27.csv", "imu28.csv", "imu29.csv", "imu30.csv",
       "imu31.csv", "imu32.csv", "imu33.csv", "imu34.csv", "imu35.csv",
       "imu36.csv", "imu37.csv", "imu38.csv", "imu39.csv", "imu40.csv",
       "imu41.csv", "imu42.csv", "imu43.csv", "imu44.csv", "imu45.csv",
       "imu46.csv", "imu47.csv", "imu48.csv", "imu49.csv", "imu50.csv",
       "imu51.csv", "imu52.csv", "imu53.csv", "imu54.csv", "imu55.csv",
       "imu56.csv", "imu57.csv", "imu58.csv", "imu59.csv", "imu60.csv",
       "imu61.csv", "imu62.csv", "imu63.csv", "imu64.csv", "imu65.csv",
       "imu66.csv", "imu67.csv", "imu68.csv", "imu69.csv", "imu70.csv",
       "imu71.csv", "imu72.csv", "imu73.csv", "imu74.csv", "imu75.csv",
       "imu76.csv", "imu77.csv", "imu78.csv",
    
       "out/acc_gyro_131_3.csv", "out/acc_gyro_151_3.csv",
       "out/acc_gyro_231_3.csv", "out/acc_gyro_251_3.csv",
       "out/acc_gyro_331_3.csv", "out/acc_gyro_351_3.csv",
       "out/acc_gyro_431_3.csv", "out/acc_gyro_451_3.csv"
      ]

vi = [
    
      "vi1.csv", "vi2.csv", "vi3.csv", "vi4.csv", "vi5.csv",
      "vi6.csv", "vi7.csv", "vi8.csv", "vi9.csv", "vi10.csv",
      "vi11.csv", "vi12.csv", "vi13.csv", "vi14.csv", "vi15.csv",
      "vi16.csv", "vi17.csv", "vi18.csv", "vi19.csv", "vi20.csv",
      "vi21.csv", "vi22.csv", "vi23.csv", "vi24.csv", "vi25.csv",
      "vi26.csv", "vi27.csv", "vi28.csv", "vi29.csv", "vi30.csv",
      "vi31.csv", "vi32.csv", "vi33.csv", "vi34.csv", "vi35.csv",
      "vi36.csv", "vi37.csv", "vi38.csv", "vi39.csv", "vi40.csv",
      "vi41.csv", "vi42.csv", "vi43.csv", "vi44.csv", "vi45.csv",
      "vi46.csv", "vi47.csv", "vi48.csv", "vi49.csv", "vi50.csv",
    
    "tango51.csv","tango52.csv","tango53.csv","tango54.csv","tango55.csv",
    "tango56.csv","tango57.csv","tango58.csv","tango59.csv","tango60.csv",
         "out/n_imu16.csv", "out/n_imu17.csv", "out/n_imu18.csv", "out/n_imu19.csv", "out/n_imu20.csv",
         "out/n_imu21.csv", "out/n_imu22.csv", "out/n_imu23.csv", "out/n_imu24.csv", "out/n_imu25.csv",
         "out/n_imu26.csv", "out/n_imu27.csv", "out/n_imu28.csv", "out/n_imu29.csv", "out/n_imu30.csv",
         "out/n_imu31.csv", "out/n_imu32.csv", "out/n_imu33.csv", "out/n_imu34.csv", "out/n_imu35.csv",
         "out/n_imu36.csv", "out/n_imu37.csv", "out/n_imu38.csv", "out/n_imu39.csv", "out/n_imu40.csv",
         "out/n_imu41.csv", "out/n_imu42.csv", "out/n_imu43.csv", "out/n_imu44.csv", "out/n_imu45.csv",
         "out/n_imu46.csv", "out/n_imu47.csv", "out/n_imu48.csv", "out/n_imu49.csv", "out/n_imu50.csv",
         "out/n_imu51.csv", "out/n_imu52.csv", "out/n_imu53.csv", "out/n_imu54.csv", "out/n_imu55.csv",
         "out/n_imu56.csv", "out/n_imu57.csv", "out/n_imu58.csv", "out/n_imu59.csv", "out/n_imu60.csv",
         "out/n_imu61.csv", "out/n_imu62.csv", "out/n_imu63.csv", "out/n_imu64.csv", "out/n_imu65.csv",
         "out/n_imu66.csv", "out/n_imu67.csv", "out/n_imu68.csv", "out/n_imu69.csv", "out/n_imu70.csv",
         "out/n_imu71.csv", "out/n_imu72.csv", "out/n_imu73.csv", "out/n_imu74.csv", "out/n_imu75.csv",
         "out/n_imu76.csv", "out/n_imu77.csv", "out/n_imu78.csv", 
    
         "out/n_acc_gyro_131_3.csv", "out/n_acc_gyro_151_3.csv", "out/n_acc_gyro_231_3.csv", 
         "out/n_acc_gyro_251_3.csv", "out/n_acc_gyro_331_3.csv", "out/n_acc_gyro_351_3.csv", 
         "out/n_acc_gyro_431_3.csv", "out/n_acc_gyro_451_3.csv"
        ]

# %%
window_size = 200
stride = 10

def load_dataset_2d(imu_data_filename, gt_data_filename, window_size=200, stride=10):
    
    imu_data = pd.read_csv(imu_data_filename).values
    gt_data = pd.read_csv(gt_data_filename).values
    
    gyro_acc_data = np.concatenate([imu_data[:, 10:13], imu_data[:, 4:7]], axis=1)

#     gyro_acc_data = imu_data[:,:]/9.81
    
#     acc_g = np.zeros(shape = (imu_data.shape[0],3))
#     acc_g[:,:] = imu_data[:, 7:10] + imu_data[:, 10:13] 
#     gyro_acc_data = np.concatenate([acc_g, imu_data[:, 4:7]], axis=1)

#     loc_data = gt_data[:, 2:4]
    loc_data = gt_data
    l0 = loc_data[window_size//2 - stride//2 - stride, :]
    l1 = loc_data[window_size//2 - stride//2, :]
    
    l_diff = l1 - l0
    psi0 = np.arctan2(l_diff[1], l_diff[0])
    init_l = l1
    init_psi = psi0

    x = []
    y_delta_l = []
    y_delta_psi = []

    for idx in range(0, gyro_acc_data.shape[0] - window_size - 1, stride):
        x.append(gyro_acc_data[idx + 1 : idx + 1 + window_size, :])

        l0_diff = loc_data[idx + window_size//2 - stride//2, :] - loc_data[idx + window_size//2 - stride//2 - stride, :]
        psi0 = np.arctan2(l0_diff[1], l0_diff[0])
        l0 = loc_data[idx + window_size//2 - stride//2, :]
        l1 = loc_data[idx + window_size//2 + stride//2, :]

        l_diff = l1 - l0
        psi1 = np.arctan2(l_diff[1], l_diff[0])
        delta_l = np.linalg.norm(l_diff)
        delta_psi = psi1 - psi0

        if delta_psi < -np.pi:
            delta_psi += 2 * np.pi
        elif delta_psi > np.pi:
            delta_psi -= 2 * np.pi

        y_delta_l.append(np.array([delta_l]))
        y_delta_psi.append(np.array([delta_psi]))


    x = np.reshape(x, (len(x), x[0].shape[0], x[0].shape[1]))
    y_delta_l = np.reshape(y_delta_l, (len(y_delta_l), y_delta_l[0].shape[0]))
    y_delta_psi = np.reshape(y_delta_psi, (len(y_delta_psi), y_delta_psi[0].shape[0]))

    return x, [y_delta_l, y_delta_psi], init_l, init_psi



window_size = 200
stride = 10

for i in range(len(imu)):
    print(i)
    x, [y_delta_l, y_delta_psi], init_l, init_psi = load_dataset_2d(imu[i],vi[i])
    acc_gyro = x.reshape(x.shape[0]*200,6)
    l_psi = np.concatenate([y_delta_l, y_delta_psi], axis=1)
    np.savetxt(imu_end[i], l_psi, delimiter=",")
    np.savetxt(imu_s[i], acc_gyro, delimiter=",")
    print(x.shape,acc_gyro.shape, l_psi.shape, y_delta_l.shape, y_delta_psi.shape, init_l, init_psi)
# Out:
# 0
# (2181, 200, 6) (436200, 6) (2181, 2) (2181, 1) (2181, 1) [0.00145435 0.00509168] 0.0
# 1
# (3360, 200, 6) (672000, 6) (3360, 2) (3360, 1) (3360, 1) [0.00017561 0.00070173] 0.0
# 2
# (2444, 200, 6) (488800, 6) (2444, 2) (2444, 1) (2444, 1) [0.00146836 0.00054272] 0.0
# 3
# (3305, 200, 6) (661000, 6) (3305, 2) (3305, 1) (3305, 1) [ 0.00137334 -0.0004176 ] 0.0
# 4
# (2122, 200, 6) (424400, 6) (2122, 2) (2122, 1) (2122, 1) [ 0.00193638 -0.00037846] 0.0
# 5
# (3293, 200, 6) (658600, 6) (3293, 2) (3293, 1) (3293, 1) [-0.00203546 -0.00060873] 0.0
# 6
# (2107, 200, 6) (421400, 6) (2107, 2) (2107, 1) (2107, 1) [-0.00735466 -0.00211897] 0.0
# 7
# (3354, 200, 6) (670800, 6) (3354, 2) (3354, 1) (3354, 1) [ 0.0036223  -0.01231129] -2.5769200388040523
